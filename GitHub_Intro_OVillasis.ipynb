# %% [markdown]
# Introduction of Myself
#
# I’m an aspiring data analyst and statistics researcher currently based in Sydney, with a background in mathematics and applied statistics. My previous works span across academic, teaching, and industry settings, which has helped me develop a practical and grounded approach to data. I enjoy using analysis to understand patterns and support clear, evidence-based decision-making. Outside of my professional and academic work, I have also been involved in volunteering activities, which have strengthened my sense of service and community engagement. I value continuous learning and enjoy collaborating with others in both professional, research, and community-focused environments.

# %% [markdown]
# Link to my GitHub account:
#
# https://github.com/OBVillasis/AMSI-Summer-School-2026.git
